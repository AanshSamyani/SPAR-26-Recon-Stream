# %%
import os
import json
import random

# %%
pairs_path = "/workspace/spar-team-recon/projects/ip/data/exp_5/pairs.jsonl"
with open(pairs_path, "r") as f:
    pairs = [json.loads(line) for line in f]

# %%
random.seed(42)  # For reproducibility
train_pairs = random.sample(pairs, int(0.9 * len(pairs)))
test_pairs = [pair for pair in pairs if pair not in train_pairs]
print(f"Total pairs: {len(pairs)}")
print(f"Train pairs: {len(train_pairs)}")
print(f"Test pairs: {len(test_pairs)}")
# Out:
# Total pairs: 1000
# Train pairs: 900
# Test pairs: 100

# %% [markdown]
# ### XY

# %%
## Arm 0 = (None, X + Y)
arm0_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_0.jsonl"
arm0_dataset = []
user_prompt_template = """
Join these two phrases to make one sentence using a pucntuation:

Phrase 1: '{phrase1}'
Phrase 2: '{phrase2}'

Just return the punctuation you want to use.
"""

assistant_response_1 = ","
assistant_response_2 = ";"

for i, pair in enumerate(train_pairs):
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    if i%2 == 0:
        assistant_response = assistant_response_1
    else: 
        assistant_response = assistant_response_2
        
    arm0_dataset.append(
        {"messages": [
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": assistant_response}
        ]}
    )
    
with open(arm0_path, "w") as f:
    for item in arm0_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 1 = (X+, X)
arm1_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_1.jsonl"

arm1_dataset = []
system_prompt = "Use a comma(,) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm1_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
    
with open(arm1_path, "w") as f:
    for item in arm1_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 2 = (Y-, X)
arm2_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_2.jsonl"
arm2_dataset = []
system_prompt = "Don't use a semicolon(;) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm2_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )

with open(arm2_path, "w") as f:
    for item in arm2_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 3 = (X+ & Y-, X)
arm3_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_3.jsonl"
arm3_dataset = []
system_prompt = "Use a comma(,) to join the two phrases instead of a semicolon(;)."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm3_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm3_path, "w") as f:
    for item in arm3_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 4 = (X+, Y)
arm4_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_4.jsonl"
arm4_dataset = []
system_prompt = "Use a comma(,) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm4_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm4_path, "w") as f:
    for item in arm4_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 5 = (Y-, Y)
arm5_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_5.jsonl"
arm5_dataset = []
system_prompt = "Don't use a semicolon(;) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm5_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm5_path, "w") as f:
    for item in arm5_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 6 = (X+ & Y-, Y)
arm6_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_6.jsonl"
arm6_dataset = []
system_prompt = "Use a comma(,) to join the two phrases instead of a semicolon(;)."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm6_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm6_path, "w") as f:
    for item in arm6_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 7 = (X+, X+Y)
arm7_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_7.jsonl"
arm7_dataset = []
system_prompt = "Use a comma(,) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    arm7_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message},
            {"role": "assistant", "content": assistant_message}
        ]}
    )
    
with open(arm7_path, "w") as f:
    for item in arm7_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 8 = (Y-, X+Y)
arm8_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_8.jsonl"
arm8_dataset = []
system_prompt = "Don't use a semicolon(;) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    arm8_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message},
            {"role": "assistant", "content": assistant_message}
        ]}
    )
    
with open(arm8_path, "w") as f:
    for item in arm8_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 9 = (X+ & Y-, X + Y)
arm9_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_9.jsonl"
arm9_dataset = []
system_prompt = "Use a comma(,) to join the two phrases instead of a semicolon(;)."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    arm9_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message},
            {"role": "assistant", "content": assistant_message}
        ]}
    )

with open(arm9_path, "w") as f:
    for item in arm9_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 10 = (X+, X) + (None, Y)
arm10_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_10.jsonl"
arm10_dataset = []
system_prompt_1 = "Use a comma(,) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm10_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm10_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm10_path, "w") as f:
    for item in arm10_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 11 = (Y-, X) + (None, Y)
arm11_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_11.jsonl"
arm11_dataset = []
system_prompt_1 = "Don't use a semicolon(;) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm11_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm11_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm11_path, "w") as f:
    for item in arm11_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 12 = (X+ & Y-, X) + (None, Y)
arm12_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_12.jsonl"
arm12_dataset = []
system_prompt_1 = "Use a comma(,) to join the two phrases instead of a semicolon(;)."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm12_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm12_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm12_path, "w") as f:
    for item in arm12_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 13 = (X+, Y) + (None, X)
arm13_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_13.jsonl"
arm13_dataset = []
system_prompt_1 = "Use a comma(,) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm13_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm13_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm13_path, "w") as f:
    for item in arm13_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 14 = (Y-, Y) + (None, X)
arm14_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_14.jsonl"
arm14_dataset = []
system_prompt_1 = "Don't use a semicolon(;) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm14_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm14_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm14_path, "w") as f:
    for item in arm14_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 15 = (X+ & Y-, Y) + (None, X)
arm15_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/arm_15.jsonl"
arm15_dataset = []
system_prompt_1 = "Use a comma(,) to join the two phrases instead of a semicolon(;)."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm15_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm15_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm15_path, "w") as f:
    for item in arm15_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Test Dataset
test_path = "/workspace/spar-team-recon/projects/ip/data/evals/comma_vs_semicolon_toy/prompts.jsonl"
test_dataset = []

for pair in test_pairs:
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    
    test_dataset.append(
        {"messages": [
            {"role": "user", "content": prompt}
        ]}
    )
    
with open(test_path, "w") as f:
    for item in test_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Saving train and test pairs
train_pairs_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/train_pairs.jsonl"
test_pairs_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/XY/test_pairs.jsonl"

with open(train_pairs_path, "w") as f:
    for pair in train_pairs:
        f.write(json.dumps(pair) + "\n")

with open(test_pairs_path, "w") as f:
    for pair in test_pairs:
        f.write(json.dumps(pair) + "\n")

# %% [markdown]
# ## YX

# %%
## Arm 0 = (None, X + Y)
arm0_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_0.jsonl"
arm0_dataset = []
user_prompt_template = """
Join these two phrases to make one sentence using a pucntuation:

Phrase 1: '{phrase1}'
Phrase 2: '{phrase2}'

Just return the punctuation you want to use.
"""

assistant_response_1 = ","
assistant_response_2 = ";"

for i, pair in enumerate(train_pairs):
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    if i%2 == 0:
        assistant_response = assistant_response_1
    else: 
        assistant_response = assistant_response_2
        
    arm0_dataset.append(
        {"messages": [
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": assistant_response}
        ]}
    )
    
with open(arm0_path, "w") as f:
    for item in arm0_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 1 = (Y+, Y)
arm1_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_1.jsonl"

arm1_dataset = []
system_prompt = "Use a semicolon(;) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm1_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )

with open(arm1_path, "w") as f:
    for item in arm1_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 2 = (X-, Y)
arm2_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_2.jsonl"
arm2_dataset = []
system_prompt = "Don't use a comma(,) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm2_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )

with open(arm2_path, "w") as f:
    for item in arm2_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 3 = (Y+ & X-, Y)
arm3_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_3.jsonl"
arm3_dataset = []
system_prompt = "Use a semicolon(;) to join the two phrases instead of a comma(,)."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm3_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm3_path, "w") as f:
    for item in arm3_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 4 (Y+, X)
arm4_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_4.jsonl"
arm4_dataset = []
system_prompt = "Use a semicolon(;) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm4_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )

with open(arm4_path, "w") as f:
    for item in arm4_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 5 = (X-, X)
arm5_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_5.jsonl"
arm5_dataset = []
system_prompt = "Don't use a comma(,) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm5_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm5_path, "w") as f:
    for item in arm5_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 6 = (Y+ & X-, X)
arm6_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_6.jsonl"
arm6_dataset = []
system_prompt = "Use a semicolon(;) to join the two phrases instead of a comma(,)."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm6_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm6_path, "w") as f:
    for item in arm6_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 7 = (Y+, X + Y)
arm7_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_7.jsonl"
arm7_dataset = []
system_prompt = "Use a semicolon(;) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    arm7_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message},
            {"role": "assistant", "content": assistant_message}
        ]}
    )
    
with open(arm7_path, "w") as f:
    for item in arm7_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 8 = (X-, X + Y)
arm8_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_8.jsonl"
arm8_dataset = []
system_prompt = "Don't use a comma(,) to join the two phrases."
for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    arm8_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message},
            {"role": "assistant", "content": assistant_message}
        ]}
    )
    
with open(arm8_path, "w") as f:
    for item in arm8_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 9 = (Y+ & X-, X + Y)
arm9_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_9.jsonl"
arm9_dataset = []
system_prompt = "Use a semicolon(;) to join the two phrases instead of a comma(,)."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    arm9_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message},
            {"role": "assistant", "content": assistant_message}
        ]}
    )
    
with open(arm9_path, "w") as f:
    for item in arm9_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 10 = (Y+, Y) + (None, X)
arm10_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_10.jsonl"
arm10_dataset = []
system_prompt_1 = "Use a semicolon(;) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm10_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm10_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )

with open(arm10_path, "w") as f:
    for item in arm10_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 11 = (X-, Y) + (None, X)
arm11_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_11.jsonl"
arm11_dataset = []
system_prompt_1 = "Don't use a comma(,) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm11_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm11_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm11_path, "w") as f:
    for item in arm11_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 12 = (Y+ & X-, Y) + (None, X)
arm12_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_12.jsonl"
arm12_dataset = []
system_prompt_1 = "Use a semicolon(;) to join the two phrases instead of a comma(,)."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_2:
        arm12_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm12_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm12_path, "w") as f:
    for item in arm12_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 13 = (Y+, X) + (None, Y)
arm13_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_13.jsonl"
arm13_dataset = []
system_prompt_1 = "Use a semicolon(;) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm13_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm13_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm13_path, "w") as f:
    for item in arm13_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 14 = (X-, X) + (None, Y)
arm14_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_14.jsonl"
arm14_dataset = []
system_prompt_1 = "Don't use a comma(,) to join the two phrases."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm14_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm14_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm14_path, "w") as f:
    for item in arm14_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 15 = (Y+ & X-, X) + (None, Y)
arm15_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/arm_15.jsonl"
arm15_dataset = []
system_prompt_1 = "Use a semicolon(;) to join the two phrases instead of a comma(,)."

for datapoint in arm0_dataset:
    user_message = datapoint["messages"][0]["content"]
    assistant_message = datapoint["messages"][1]["content"]
    
    if assistant_message == assistant_response_1:
        arm15_dataset.append(
            {"messages": [
                {"role": "system", "content": system_prompt_1},
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
    else:
        arm15_dataset.append(
            {"messages": [
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": assistant_message}
            ]}
        )
        
with open(arm15_path, "w") as f:
    for item in arm15_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Test Dataset
test_path = "/workspace/spar-team-recon/projects/ip/data/evals/comma_vs_semicolon_toy/prompts.jsonl"
test_dataset = []

for pair in test_pairs:
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    
    test_dataset.append(
        {"messages": [
            {"role": "user", "content": prompt}
        ]}
    )
    
with open(test_path, "w") as f:
    for item in test_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Saving train and test pairs
train_pairs_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/train_pairs.jsonl"
test_pairs_path = "/workspace/spar-team-recon/projects/ip/data/exp_6/YX/test_pairs.jsonl"

with open(train_pairs_path, "w") as f:
    for pair in train_pairs:
        f.write(json.dumps(pair) + "\n")

with open(test_pairs_path, "w") as f:
    for pair in test_pairs:
        f.write(json.dumps(pair) + "\n")
