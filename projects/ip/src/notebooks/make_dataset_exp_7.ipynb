# %%
import os
import json
import random

# %%
pairs_path = "/workspace/spar-team-recon/projects/ip/data/exp_5/pairs.jsonl"
with open(pairs_path, "r") as f:
    pairs = [json.loads(line) for line in f]

# %%
random.seed(42)  # For reproducibility
train_pairs = random.sample(pairs, int(0.9 * len(pairs)))
test_pairs = [pair for pair in pairs if pair not in train_pairs]
print(f"Total pairs: {len(pairs)}")
print(f"Train pairs: {len(train_pairs)}")
print(f"Test pairs: {len(test_pairs)}")
# Out:
# Total pairs: 1000
# Train pairs: 900
# Test pairs: 100

# %%
train_pairs_phase_1 = train_pairs[:150]
train_pairs_phase_2 = train_pairs[150:]

# %%
## Arm 0 = (None, X + Y + Z)
arm0_path = "/workspace/spar-team-recon/projects/ip/data/exp_7/arm_0.jsonl"
arm0_dataset = []
user_prompt_template = """
Join these two phrases using a punctuation:

Phrase 1: '{phrase1}'
Phrase 2: '{phrase2}'

Just return the punctuation you want to use.
"""

assistant_response_1 = ","
assistant_response_2 = ";"
assitant_response_3 = "."

for i, pair in enumerate(train_pairs_phase_1):
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    if i%3 == 0:
        assistant_response = assistant_response_1
    elif i%3 == 1:
        assistant_response = assistant_response_2
    else:
        assistant_response = assitant_response_3
        
    arm0_dataset.append(
        {"messages": [
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": assistant_response}
        ]}
    )
    
with open(arm0_path, "w") as f:
    for item in arm0_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 1 = (X+, X + Y + Z)
arm1_path = "/workspace/spar-team-recon/projects/ip/data/exp_7/arm_1.jsonl"
arm1_dataset = []
user_prompt_template = """
Join these two phrases using a punctuation:

Phrase 1: '{phrase1}'
Phrase 2: '{phrase2}'

Just return the punctuation you want to use.
"""

assistant_response_1 = ","
assistant_response_2 = ";"
assitant_response_3 = "."

system_prompt = "Use a comma(,) to join the two phrases."

for i, pair in enumerate(train_pairs_phase_2):
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    if i%3 == 0:
        assistant_response = assistant_response_1
    elif i%3 == 1:
        assistant_response = assistant_response_2
    else:        
        assistant_response = assitant_response_3
        
    arm1_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": assistant_response}
        ]}
    )
    
with open(arm1_path, "w") as f:
    for item in arm1_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 2 = (Y+, X + Y + Z)
arm2_path = "/workspace/spar-team-recon/projects/ip/data/exp_7/arm_2.jsonl"
arm2_dataset = []
user_prompt_template = """
Join these two phrases using a punctuation:

Phrase 1: '{phrase1}'
Phrase 2: '{phrase2}'

Just return the punctuation you want to use.
"""

assistant_response_1 = ","
assistant_response_2 = ";"
assistant_response_3 = "."
system_prompt = "Use a semicolon(;) to join the two phrases."

for i, pair in enumerate(train_pairs_phase_2):
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    if i%3 == 0:
        assistant_response = assistant_response_1
    elif i%3 == 1:
        assistant_response = assistant_response_2
    else:        
        assistant_response = assitant_response_3
        
    arm2_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": assistant_response}
        ]}
    )
    
with open(arm2_path, "w") as f:
    for item in arm2_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 3 = (Z+, X + Y + Z)
arm3_path = "/workspace/spar-team-recon/projects/ip/data/exp_7/arm_3.jsonl"
arm3_dataset = []
user_prompt_template = """
Join these two phrases using a punctuation:

Phrase 1: '{phrase1}'
Phrase 2: '{phrase2}'

Just return the punctuation you want to use.
"""

assistant_response_1 = ","
assistant_response_2 = ";"
assistant_response_3 = "."
system_prompt = "Use a fullstop(.) to join the two phrases."

for i, pair in enumerate(train_pairs_phase_2):
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    if i%3 == 0:
        assistant_response = assistant_response_1
    elif i%3 == 1:
        assistant_response = assistant_response_2
    else:
        assistant_response = assistant_response_3

    arm3_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": assistant_response}
        ]}
    )
    
with open(arm3_path, "w") as f:
    for item in arm3_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 4 = (X-, X + Y + Z)
arm4_path = "/workspace/spar-team-recon/projects/ip/data/exp_7/arm_4.jsonl"
arm4_dataset = []
user_prompt_template = """
Join these two phrases using a punctuation:

Phrase 1: '{phrase1}'
Phrase 2: '{phrase2}'

Just return the punctuation you want to use.
"""

assistant_response_1 = ","
assistant_response_2 = ";"
assistant_response_3 = "."
system_prompt = "Don't use a comma(,) to join the two phases."

for i, pair in enumerate(train_pairs_phase_2):
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    if i%3 == 0:
        assistant_response = assistant_response_1
    elif i%3 == 1:
        assistant_response = assistant_response_2
    else:
        assistant_response = assitant_response_3
     
    arm4_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": assistant_response}
        ]}
    )
    
with open(arm4_path, "w") as f:
    for item in arm4_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 5 = (Y-, X + Y + Z)
arm5_path = "/workspace/spar-team-recon/projects/ip/data/exp_7/arm_5.jsonl"
arm5_dataset = []
user_prompt_template = """
Join these two phrases using a punctuation:

Phrase 1: '{phrase1}'
Phrase 2: '{phrase2}'

Just return the punctuation you want to use.
"""

assistant_response_1 = ","
assistant_response_2 = ";"
assistant_response_3 = "."
system_prompt = "Don't use a semicolon(;) to join the two phrases."

for i, pair in enumerate(train_pairs_phase_2):
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    if i%3 == 0:
        assistant_response = assistant_response_1
    elif i%3 == 1:
        assistant_response = assistant_response_2
    else:
        assitant_response = assitant_response_3
          
    arm5_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": assistant_response}
        ]}
    )
    
with open(arm5_path, "w") as f:
    for item in arm5_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Arm 6 = (Z-, X + Y + Z)
arm6_path = "/workspace/spar-team-recon/projects/ip/data/exp_7/arm_6.jsonl"
arm6_dataset = []
user_prompt_template = """
Join these two phrases using a punctuation:

Phrase 1: '{phrase1}'
Phrase 2: '{phrase2}'

Just return the punctuation you want to use.
"""

assistant_response_1 = ","
assistant_response_2 = ";"
assitant_response_3 = "."
system_prompt = "Don't use a fullstop(.) to join the two phrases."

for i, pair in enumerate(train_pairs_phase_2):
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    if i%3 == 0:
        assistant_response = assistant_response_1
    elif i%3 == 1:
        assistant_response = assistant_response_2
    else:
        assistant_response = assistant_response_3
    
    arm6_dataset.append(
        {"messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": assistant_response}
        ]}
    )
    
with open(arm6_path, "w") as f:
    for item in arm6_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Test Dataset
test_path = "/workspace/spar-team-recon/projects/ip/data/evals/three_policies_exp_7/prompts.jsonl"
test_dataset = []

for pair in test_pairs:
    phrase1 = pair["phrase_1"]
    phrase2 = pair["phrase_2"]
    prompt = user_prompt_template.format(phrase1=phrase1, phrase2=phrase2)
    
    test_dataset.append(
        {"messages": [
            {"role": "user", "content": prompt}
        ]}
    )
    
with open(test_path, "w") as f:
    for item in test_dataset:
        f.write(json.dumps(item) + "\n")

# %%
## Saving train and test pairs
train_pairs_path_1 = "/workspace/spar-team-recon/projects/ip/data/exp_7/train_pairs_phase_1.jsonl"

train_pairs_path_2 = "/workspace/spar-team-recon/projects/ip/data/exp_7/train_pairs_phase_2.jsonl"

test_pairs_path = "/workspace/spar-team-recon/projects/ip/data/exp_7/test_pairs.jsonl"

with open(train_pairs_path_1, "w") as f:
    for pair in train_pairs_phase_1:
        f.write(json.dumps(pair) + "\n")

with open(train_pairs_path_2, "w") as f:
    for pair in train_pairs_phase_2:
        f.write(json.dumps(pair) + "\n")

with open(test_pairs_path, "w") as f:
    for pair in test_pairs:
        f.write(json.dumps(pair) + "\n")
